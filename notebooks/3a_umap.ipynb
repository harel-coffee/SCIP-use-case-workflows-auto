# %%
# default_exp umap

# %% [markdown]
# # UMAP
#
# > API details.

# %%
#hide
from nbdev.showdoc import *

# %%
# %load common.py
# export

import pandas
import os
import numpy
import seaborn
import logging
import matplotlib.pyplot as plt
from importlib import reload

numpy.random.seed(42)

# %%
# export 

import umap
import fcsparser
from joblib import load, dump

# %%
meta, df = fcsparser.parse("D:/Experiment_data/weizmann/EhV/201/aggregates/non_intensity_T0234567_R123.fcs")
df_meta = df[["label", "replicate", "timepoint"]].astype(int)
df_meta["timepoint"] = df_meta["timepoint"].map(lambda a: meta["timepoint"].split(",")[a])
df_meta["replicate"] = df_meta["replicate"].map(lambda a: meta["replicate"].split(",")[a])
df = df.drop(columns=["label", "replicate", "timepoint"])

# %%
projector = umap.UMAP()
projection = projector.fit_transform(df)
projection = pandas.DataFrame(projection, columns=["dim_1", "dim_2"])

# %%
dump(projection, "D:/Experiment_data/weizmann/EhV/201/aggregates/umap_non_intensity_T0234567_R123.dat")
# Out:
# ['D:/Experiment_data/weizmann/EhV/201/aggregates/umap_non_intensity_T0234567_R123.dat']

# %%
grid = seaborn.FacetGrid(col="timepoint", hue="replicate", data=pandas.concat([df, df_meta, projection], axis=1))
grid = grid.map(plt.scatter, "dim_1", "dim_2", s=0.5, linewidths=0, edgecolors=None, alpha=0.5)
grid.add_legend()

for handle in grid._legend.legendHandles:
    handle.set_sizes([30])
    handle.set_alpha(1.0)

# %% [markdown]
# ## BF

# %%
todrop = df.filter(regex="(?i).*(TMR|MCP|Cy5|DAPI|M06|Ch06|M07|Similarity)")
df_bf = df.drop(columns=todrop)

# %%
df_bf.head()
# Out:
#     AreaM01  AreaLevelSet(M01BFDim5)  MaxPixelLevelSet(M01BFDim5)BF  \
# 0 -0.360266                -0.489726                       0.545377
# 1 -1.054074                 0.963268                      -0.338201
# 2  0.007877                -0.237031                       0.095262
# 3  0.630888                 0.078837                      -0.581384
# 4  1.310537                 0.015663                      -0.552736
#
#    AspectRatioLevelSet(M01BFDim5)  GradientRMSM01BF  AngleM01  \
# 0                        0.422263         -0.561803 -1.017752
# 1                       -0.339254          0.349700  1.501196
# 2                        0.881175          0.684847  1.555930
# 3                        0.621299          0.917606  1.037936
# 4                       -0.791075         -2.198850 -0.066139
#
#    HeightObject(M01BFTight)  MinPixelLevelSet(M01BFDim5)BF  \
# 0                  1.000086                       0.392709
# 1                  0.629514                       0.235763
# 2                 -0.111631                       0.096121
# 3                 -0.852776                      -0.545140
# 4                 -1.223349                      -0.084850
#
#    CentroidYObject(M01BFTight)  AspectRatioIntensityObject(M01BFTight)BF  ...  \
# 0                    -0.051788                                 -1.255205  ...
# 1                    -1.094018                                  0.478160  ...
# 2                     1.438205                                  0.250212  ...
# 3                     0.945624                                 -0.509781  ...
# 4                    -2.832966                                  1.110029  ...
#
#    AspectRatioIntensityLevelSet(M01BFDim5)BF  \
# 0                                   1.220630
# 1                                  -0.571321
# 2                                   0.351382
# 3                                   0.283813
# 4                                  -1.586028
#
#    GradientRMSLevelSet(M01BFDim5)BF  MeanPixelObject(M01BFTight)BF  \
# 0                          0.610526                      -0.934192
# 1                          0.330142                       1.290296
# 2                          0.381059                       0.175500
# 3                          0.699018                       0.538141
# 4                         -2.133334                       1.377900
#
#    CentroidYIntensityM01BF  MaxPixelM01BF  MedianPixelLevelSet(M01BFDim5)BF  \
# 0                 0.166228      -0.091232                         -0.466496
# 1                -1.135900      -0.642681                          0.077533
# 2                 1.277209      -0.602496                         -0.484861
# 3                 0.934039       0.160051                          0.464639
# 4                -2.532064      -0.774068                          0.083806
#
#    MedianPixelObject(M01BFTight)BF  GradientMaxM01BF  MeanPixelM01BF  \
# 0                         0.462132          0.043642        0.671636
# 1                        -1.403891          0.104332       -1.774979
# 2                        -0.218857          0.303522       -0.663559
# 3                        -1.013830         -1.196783       -0.672166
# 4                        -1.495653         -0.581514       -3.299746
#
#    AreaObject(M01BFTight)
# 0                0.657451
# 1                0.796741
# 2               -0.158387
# 3               -1.352298
# 4               -0.755343
#
# [5 rows x 72 columns]

# %%
projector = umap.UMAP()
projection = projector.fit_transform(df_bf )
projection = pandas.DataFrame(projection, columns=["dim_1", "dim_2"])

# %%
dump(projection, "D:/Experiment_data/weizmann/EhV/201/aggregates/umap_non_intensity_T0234567_R123_bf.dat")
# Out:
# ['D:/Experiment_data/weizmann/EhV/201/aggregates/umap_non_intensity_T0234567_R123_bf.dat']

# %%
grid = seaborn.FacetGrid(col="timepoint", hue="replicate", data=pandas.concat([df, df_meta, projection], axis=1))
grid = grid.map(plt.scatter, "dim_1", "dim_2", s=0.5, linewidths=0, edgecolors=None, alpha=0.5)
grid.add_legend()

for handle in grid._legend.legendHandles:
    handle.set_sizes([30])
    handle.set_alpha(1.0)
