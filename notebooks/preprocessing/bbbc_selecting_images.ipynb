# %% [markdown]
# # BBBC: selecting images

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %load ../common_.py
import sys
sys.path.append("../..")
from common import *

# %%
data_dir = Path("/data/Experiment_data/BBBC021/")

# %%
data_dir = Path(os.environ["VSC_DATA_VO_USER"]) / "datasets/BBBC021"

# %%
moa = pandas.read_csv(data_dir / "BBBC021_v1_moa.csv")
image = pandas.read_csv(data_dir / "BBBC021_v1_image.csv")

# %%
moa_image = moa.merge(image, left_on=("compound", "concentration"), right_on=("Image_Metadata_Compound", "Image_Metadata_Concentration"))

# %%
moa_image["Image_FileName_DAPI"].unique().shape
# Out:
# (3848,)

# %%
moa["moa"].unique()
# Out:
# array(['Epithelial', 'Protein synthesis', 'Aurora kinase inhibitors',
#        'Actin disruptors', 'Protein degradation', 'DNA replication',
#        'Eg5 inhibitors', 'Microtubule stabilizers', 'DNA damage',
#        'Kinase inhibitors', 'Microtubule destabilizers',
#        'Cholesterol-lowering', 'DMSO'], dtype=object)

# %%
seaborn.countplot(data=moa, y="moa", order=sorted(moa.moa.unique()))
# Out:
# <AxesSubplot:xlabel='count', ylabel='moa'>
